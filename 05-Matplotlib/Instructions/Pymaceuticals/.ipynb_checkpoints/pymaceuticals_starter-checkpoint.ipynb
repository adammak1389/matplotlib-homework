# %% [markdown]
# ## Observations and Insights
#
# ## 1. There is a strong correlation between average tumor volume and mouse weight.
# ## 2. Over time, Capomulin as a drug regimen decreases tumor size in mice.
# ## 3. Stelasyn was the only treatment to have 24 mice allocated.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
from scipy.stats import linregress

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset
mouse_data_combined_df = pd.merge(mouse_metadata, study_results, on="Mouse ID", how="outer")

# Display the data table for preview
mouse_data_combined_df
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Checking the number of mice.
mouse_data_combined_df["Mouse ID"].nunique()
# Out:
# 249

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint.
mouse_data_combined_df[mouse_data_combined_df.duplicated(['Mouse ID', 'Timepoint'], keep=False)]

# Optional: Get all the data for the duplicate mouse ID. 

duplicated_mouse_data_combined_df = mouse_data_combined_df[mouse_data_combined_df.duplicated(['Mouse ID', 'Timepoint'], keep=False)]
duplicated_mouse_data_combined_df
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 908     g989     Propriva  Female          21          26          0
# 909     g989     Propriva  Female          21          26          0
# 910     g989     Propriva  Female          21          26          5
# 911     g989     Propriva  Female          21          26          5
# 912     g989     Propriva  Female          21          26         10
# 913     g989     Propriva  Female          21          26         10
# 914     g989     Propriva  Female          21          26         15
# 915     g989     Propriva  Female          21          26         15
# 916     g989     Propriva  Female          21          26         20
# 917     g989     Propriva  Female          21          26         20
#
#      Tumor Volume (mm3)  Metastatic Sites
# 908           45.000000                 0
# 909           45.000000                 0
# 910           48.786801                 0
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
cleaned_mouse_data_df = mouse_data_combined_df.drop_duplicates(subset=['Mouse ID', 'Timepoint'], keep='first')
cleaned_mouse_data_df
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Checking the number of mice in the clean DataFrame.
cleaned_mouse_data_df["Mouse ID"].nunique()
# Out:
# 249

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
regimen_summary_df = cleaned_mouse_data_df.groupby('Drug Regimen').agg(
             regimen_mean=('Tumor Volume (mm3)', 'mean'),
             regimen_median=('Tumor Volume (mm3)', 'median'),
             regimen_variance=('Tumor Volume (mm3)', 'var'),
             regimen_std_deviation=('Tumor Volume (mm3)', 'std'),
             regimen_sem=('Tumor Volume (mm3)', 'sem'))
regimen_summary_df
# This method produces everything in a single groupby function
# Out:
#               regimen_mean  regimen_median  regimen_variance  \
# Drug Regimen
# Capomulin        40.675741       41.557809         24.947764
# Ceftamin         52.591172       51.776157         39.290177
# Infubinol        52.884795       51.820584         43.128684
# Ketapril         55.235638       53.698743         68.553577
# Naftisol         54.331565       52.509285         66.173479
# Placebo          54.033581       52.288934         61.168083
# Propriva         52.393463       50.909965         43.138803
# Ramicane         40.216745       40.673236         23.486704
# Stelasyn         54.233149       52.431737         59.450562
# Zoniferol        53.236507       51.818479         48.533355
#
#               regimen_std_deviation  regimen_sem
# Drug Regimen
# Capomulin                  4.994774     0.329346
# Ceftamin                   6.268188     0.469821
# Infubinol                  6.567243     0.492236
# Ketapril                   8.279709     0.603860
# ...

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of mice for each treatment throughout the course of the study using pandas.
total_mice_treatments_df = pd.DataFrame(cleaned_mouse_data_df.groupby("Drug Regimen")["Mouse ID"].nunique())

total_mice_treatments_df
# Out:
#               Mouse ID
# Drug Regimen
# Capomulin           25
# Ceftamin            25
# Infubinol           25
# Ketapril            25
# Naftisol            25
# Placebo             25
# Propriva            25
# Ramicane            25
# Stelasyn            24
# Zoniferol           25

# %%
total_mice_treatments_df.rename(columns={"Mouse ID": "Total Mice"})
# Out:
#               Total Mice
# Drug Regimen
# Capomulin             25
# Ceftamin              25
# Infubinol             25
# Ketapril              25
# Naftisol              25
# Placebo               25
# Propriva              25
# Ramicane              25
# Stelasyn              24
# Zoniferol             25

# %%
total_mice_treatments_df.plot(kind="bar", figsize=(20,5))

# set a title for the chart
plt.title("Total Mice Per Treatment")
plt.ylabel("Count of Mice")
plt.grid()
plt.show()

# %%
# Generate a bar plot showing the total number of mice for each treatment throughout the course of the study using pyplot.

mice_counts = [25, 25, 25, 25, 25, 25, 25, 25, 24, 25]
x_axis = np.arange(len(mice_counts))

plt.bar(x_axis, mice_counts, color='r', alpha=1, align="center")
plt.title("Total Mice Per Treatment")
plt.xlabel("Drug Regimen")
plt.ylabel("Count of Mice")
# Tell matplotlib where we would like to place each of our x axis headers
plt.xticks(x_axis, ["Capomulin", "Ceftamin", "Infubinol", "Ketapril", "Naftisol", "Placebo", "Propriva", "Ramicane", "Stelasyn", "Zoniferol" ], rotation=90)
# set the x limits of the current chart
plt.xlim(-0.75, x_axis[-1] + 0.75)
# set the y limits of the current chart
plt.ylim(0, max(mice_counts)*1.1)
# Out:
# (0, 27.500000000000004)

# %%
# Generate a pie plot showing the distribution of female versus male mice using pandas
male_female_mice_df = pd.DataFrame(cleaned_mouse_data_df.groupby("Sex")["Mouse ID"].nunique())

male_female_mice_df
# Out:
#         Mouse ID
# Sex
# Female       124
# Male         125

# %%
male_female_mice_df.rename(columns={"Mouse ID": "Total Mice"})
# Out:
#         Total Mice
# Sex
# Female         124
# Male           125

# %%
male_female_mice_df.groupby(['Sex']).sum().plot(kind='pie', y='Mouse ID', figsize=(10,5), autopct='%1.1f%%')

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
gender = ["Male", "Female"]
gender_count = [125,124]
colors = ["red", "blue"]


plt.pie(gender_count, labels=gender, colors=colors, autopct="%1.1f%%", startangle=140)
plt.axis("equal")
# Out:
# (-1.1092527659968812,
#  1.1222566193373384,
#  -1.109449931456455,
#  1.1211462801337193)

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin


# Start by getting the last (greatest) timepoint for each mouse

greatest_timepoint_df = pd.DataFrame(cleaned_mouse_data_df.groupby("Mouse ID")["Timepoint"].max())
greatest_timepoint_df
# Out:
#           Timepoint
# Mouse ID
# a203             45
# a251             45
# a262             45
# a275             45
# a366             30
# ...             ...
# z435             10
# z578             45
# z581             45
# z795             45
# z969             45
#
# [249 rows x 1 columns]

# %%
# Merge this group df with the original dataframe to get the tumor volume at the last timepoint
timepoint_data_combined_df = pd.merge(cleaned_mouse_data_df, greatest_timepoint_df, on=["Mouse ID","Timepoint"], how="inner")
timepoint_data_combined_df
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 0       k403     Ramicane    Male          21          16         45
# 1       s185    Capomulin  Female           3          17         45
# 2       x401    Capomulin  Female          16          15         45
# 3       m601    Capomulin    Male          22          17         45
# 4       g791     Ramicane    Male          11          16         45
# ..       ...          ...     ...         ...         ...        ...
# 244     z314     Stelasyn  Female          21          28          5
# 245     z435     Propriva  Female          12          26         10
# 246     z581    Infubinol  Female          24          25         45
# 247     z795     Naftisol  Female          13          29         45
# 248     z969     Naftisol    Male           9          30         45
#
#      Tumor Volume (mm3)  Metastatic Sites
# 0             22.050126                 1
# 1             23.343598                 1
# ...

# %%
timepoint_data_combined_df = timepoint_data_combined_df[~timepoint_data_combined_df['Drug Regimen'].isin(['Ketapril', 'Naftisol', 'Placebo', 'Propriva', 'Stelasyn', 'Zoniferol'])]
timepoint_data_combined_df
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 0       k403     Ramicane    Male          21          16         45
# 1       s185    Capomulin  Female           3          17         45
# 2       x401    Capomulin  Female          16          15         45
# 3       m601    Capomulin    Male          22          17         45
# 4       g791     Ramicane    Male          11          16         45
# ..       ...          ...     ...         ...         ...        ...
# 235     x822     Ceftamin    Male           3          29         45
# 237     y163    Infubinol  Female          17          27         45
# 241     y769     Ceftamin  Female           6          27         45
# 242     y865     Ceftamin    Male          23          26         45
# 246     z581    Infubinol  Female          24          25         45
#
#      Tumor Volume (mm3)  Metastatic Sites
# 0             22.050126                 1
# 1             23.343598                 1
# ...

# %%
final_timepoint_data_combined_df = timepoint_data_combined_df.drop(timepoint_data_combined_df.columns[[2, 3, 4, 7]], axis=1)
final_timepoint_data_combined_df
# Out:
#     Mouse ID Drug Regimen  Timepoint  Tumor Volume (mm3)
# 0       k403     Ramicane         45           22.050126
# 1       s185    Capomulin         45           23.343598
# 2       x401    Capomulin         45           28.484033
# 3       m601    Capomulin         45           28.430964
# 4       g791     Ramicane         45           29.128472
# ..       ...          ...        ...                 ...
# 235     x822     Ceftamin         45           61.386660
# 237     y163    Infubinol         45           67.685569
# 241     y769     Ceftamin         45           68.594745
# 242     y865     Ceftamin         45           64.729837
# 246     z581    Infubinol         45           62.754451
#
# [100 rows x 4 columns]

# %%
final_timepoint_data_combined_df.rename(columns={"Tumor Volume (mm3)": "Final Tumor Volume (mm3)",
                                                "Timepoint": "Final Timepoint"}, inplace=True)

# %%
# Put treatments into a list for for loop (and later for plot labels)
treatments_list = pd.Series(final_timepoint_data_combined_df["Drug Regimen"].drop_duplicates())

# Create empty list to fill with tumor vol data (for plotting)

# %%
# Calculate the IQR and quantitatively determine if there are any potential outliers. 
capomulin_tumor_vol = final_timepoint_data_combined_df.loc[final_timepoint_data_combined_df["Drug Regimen"] == "Capomulin"]
ramicane_tumor_vol = final_timepoint_data_combined_df.loc[final_timepoint_data_combined_df["Drug Regimen"] == "Ramicane"]
infubinol_tumor_vol = final_timepoint_data_combined_df.loc[final_timepoint_data_combined_df["Drug Regimen"] == "Infubinol"]
ceftamin_tumor_vol = final_timepoint_data_combined_df.loc[final_timepoint_data_combined_df["Drug Regimen"] == "Ceftamin"]

infubinol_quart_range = infubinol_tumor_vol["Final Tumor Volume (mm3)"].quantile([.25,.5,.75])
ceftamin_quart_range = ceftamin_tumor_vol["Final Tumor Volume (mm3)"].quantile([.25,.5,.75])
ramicane_quart_range = ramicane_tumor_vol["Final Tumor Volume (mm3)"].quantile([.25,.5,.75])
capomulin_quart_range = capomulin_tumor_vol["Final Tumor Volume (mm3)"].quantile([.25,.5,.75])

capomulin_iqr = capomulin_quart_range[0.75]-capomulin_quart_range[0.25]
ramicane_iqr = ramicane_quart_range[0.75]-ramicane_quart_range[0.25]
infubinol_iqr = infubinol_quart_range[0.75]-infubinol_quart_range[0.25]
ceftamin_iqr = ceftamin_quart_range[0.75]-ceftamin_quart_range[0.25]
    # Locate the rows which contain mice on each drug and get the tumor volumes
    
    
    # add subset 
    
    
    # Determine outliers using upper and lower bounds
capomulin_lower_bound = capomulin_quart_range[0.25] - (1.5 * capomulin_iqr)
capomulin_upper_bound = capomulin_quart_range[0.75] + (1.5 * capomulin_iqr)
capomulin_outliers = capomulin_tumor_vol.loc[(capomulin_tumor_vol["Final Tumor Volume (mm3)"] > capomulin_upper_bound) |
                                             (capomulin_tumor_vol["Final Tumor Volume (mm3)"] < capomulin_lower_bound)]

ramicane_lower_bound = ramicane_quart_range[0.25] - (1.5 * ramicane_iqr)
ramicane_upper_bound = ramicane_quart_range[0.75] + (1.5 * ramicane_iqr)
ramicane_outliers = ramicane_tumor_vol.loc[(ramicane_tumor_vol["Final Tumor Volume (mm3)"] > ramicane_upper_bound) |
                                             (ramicane_tumor_vol["Final Tumor Volume (mm3)"] < ramicane_lower_bound)]

infubinol_lower_bound = infubinol_quart_range[0.25] - (1.5 * infubinol_iqr)
infubinol_upper_bound = infubinol_quart_range[0.75] + (1.5 * infubinol_iqr)
infubinol_outliers = infubinol_tumor_vol.loc[(infubinol_tumor_vol["Final Tumor Volume (mm3)"] > infubinol_upper_bound) |
                                             (infubinol_tumor_vol["Final Tumor Volume (mm3)"] < infubinol_lower_bound)]

ceftamin_lower_bound = ceftamin_quart_range[0.25] - (1.5 * ceftamin_iqr)
ceftamin_upper_bound = ceftamin_quart_range[0.75] + (1.5 * ceftamin_iqr)
ceftamin_outliers = ceftamin_tumor_vol.loc[(ceftamin_tumor_vol["Final Tumor Volume (mm3)"] > ceftamin_upper_bound) |
                                             (ceftamin_tumor_vol["Final Tumor Volume (mm3)"] < ceftamin_lower_bound)]

outliers_combined = capomulin_outliers.append(ramicane_outliers)
outliers_combined = outliers_combined.append(infubinol_outliers)
outliers_combined = outliers_combined.append(ceftamin_outliers)
outliers_combined
# Out:
#    Mouse ID Drug Regimen  Final Timepoint  Final Tumor Volume (mm3)
# 74     c326    Infubinol                5                 36.321346

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest

fig, axs = plt.subplots(2, 2)
fig.suptitle("Final Tumor Sizes by Focus Treatment")

axs[0, 0].boxplot(capomulin_tumor_vol["Final Tumor Volume (mm3)"])
axs[0, 0].set_title("Capomulin Tumor Sizes")

axs[0, 1].boxplot(ramicane_tumor_vol["Final Tumor Volume (mm3)"])
axs[0, 1].set_title("Ramicane Tumor Sizes")

axs[1, 0].boxplot(infubinol_tumor_vol["Final Tumor Volume (mm3)"])
axs[1, 0].set_title("Infubinol Tumor Sizes")

axs[1, 1].boxplot(ceftamin_tumor_vol["Final Tumor Volume (mm3)"])
axs[1, 1].set_title("Ceftamin Tumor Sizes")

plt.figure(figsize=(20,20))
fig.tight_layout(pad=3.0)
plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of time point versus tumor volume for a mouse treated with Capomulin
capomulin_mouse_df = cleaned_mouse_data_df[cleaned_mouse_data_df["Mouse ID"] == "m601"] 
capomulin_mouse_df
# Out:
#    Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 30     m601    Capomulin  Male          22          17          0
# 31     m601    Capomulin  Male          22          17          5
# 32     m601    Capomulin  Male          22          17         10
# 33     m601    Capomulin  Male          22          17         15
# 34     m601    Capomulin  Male          22          17         20
# 35     m601    Capomulin  Male          22          17         25
# 36     m601    Capomulin  Male          22          17         30
# 37     m601    Capomulin  Male          22          17         35
# 38     m601    Capomulin  Male          22          17         40
# 39     m601    Capomulin  Male          22          17         45
#
#     Tumor Volume (mm3)  Metastatic Sites
# 30           45.000000                 0
# 31           41.408591                 1
# 32           36.825367                 1
# 33           35.464612                 1
# ...

# %%
timepoint = (0, 5, 10, 15, 20, 25, 30, 35, 40, 45)
timepoint

tumor_volume = [45.000000, 41.408591, 36.825367, 35.464612, 34.255732, 33.118756, 31.758275, 30.834357, 31.378045, 28.430964]
tumor_volume
# Out:
# [45.0,
#  41.408591,
#  36.825367,
#  35.464612,
#  34.255732,
#  33.118756,
#  31.758275,
#  30.834357,
#  31.378045,
#  28.430964]

# %%
plt.plot(timepoint, tumor_volume, marker='o', color='red', label="Tumor Volume")
plt.legend(loc="lower right")
plt.xlabel("Timepoint")
plt.ylabel("Tumor Volume (mm3)")
plt.title("Tumor Volume Over Time")
plt.grid()

# %%
# Generate a scatter plot of mouse weight versus average tumor volume for the Capomulin regimen
capomulin_mouse_weight_df = cleaned_mouse_data_df[cleaned_mouse_data_df["Drug Regimen"] == "Capomulin"]
capomulin_mouse_weight_df
# Out:
#      Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 10       s185    Capomulin  Female           3          17          0
# 11       s185    Capomulin  Female           3          17          5
# 12       s185    Capomulin  Female           3          17         10
# 13       s185    Capomulin  Female           3          17         15
# 14       s185    Capomulin  Female           3          17         20
# ...       ...          ...     ...         ...         ...        ...
# 440      i557    Capomulin  Female           1          24         45
# 1452     r157    Capomulin    Male          22          25          0
# 1453     r157    Capomulin    Male          22          25          5
# 1454     r157    Capomulin    Male          22          25         10
# 1455     r157    Capomulin    Male          22          25         15
#
#       Tumor Volume (mm3)  Metastatic Sites
# 10             45.000000                 0
# ...

# %%
capomulin_mouse_weight_filtered_df = capomulin_mouse_weight_df.groupby('Mouse ID').agg(
             mouse_weight=('Weight (g)', 'first'),
             avg_tumor_vol=('Tumor Volume (mm3)', 'mean'))
capomulin_mouse_weight_filtered_df
# Out:
#           mouse_weight  avg_tumor_vol
# Mouse ID
# b128                22      41.963636
# b742                21      40.083699
# f966                17      36.505973
# g288                19      41.990097
# g316                22      44.613344
# i557                24      44.805810
# i738                20      39.141053
# j119                23      44.465236
# j246                21      43.216925
# l509                21      44.434474
# l897                19      42.507261
# m601                17      34.847470
# m957                19      39.049816
# r157                25      45.798970
# r554                17      36.509212
# r944                25      43.367364
# s185                17      34.559143
# s710                23      42.803733
# t565                17      39.328725
# u364                17      39.887495
# v923                21      41.581595
# w150                23      41.384825
# w914                21      41.352452
# ...

# %%
capomulin_mouse_weight_filtered_df.plot(kind="scatter", x="mouse_weight", y="avg_tumor_vol", grid=True, title="Weight (g) vs Tumor Volume (mm3)")

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen

correlation = st.pearsonr(capomulin_mouse_weight_filtered_df["mouse_weight"],capomulin_mouse_weight_filtered_df["avg_tumor_vol"])
print(f"The correlation between both factors is {round(correlation[0],2)}")
# Out:
# The correlation between both factors is 0.84

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(capomulin_mouse_weight_filtered_df["mouse_weight"], capomulin_mouse_weight_filtered_df["avg_tumor_vol"])
print(slope,intercept,rvalue,pvalue,stderr)

regress_values = capomulin_mouse_weight_filtered_df["mouse_weight"] * slope + intercept
# Out:
# 0.9544396890241045 21.552160532685015 0.8419363424694718 1.3225722434712642e-07 0.1275435903320134

# %%
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(capomulin_mouse_weight_filtered_df["mouse_weight"], capomulin_mouse_weight_filtered_df["avg_tumor_vol"])

print(f"The Linear Regression equation is: {line_eq}")
plt.plot(capomulin_mouse_weight_filtered_df["mouse_weight"], regress_values, "r-")
plt.annotate(line_eq, (5,5), fontsize=10, color="red")
plt.xlabel('Mouse Weight (g)')
plt.ylabel('Average Tumor Volume (mm3)')
plt.show()
# Out:
# The Linear Regression equation is: y = 0.95x + 21.55
